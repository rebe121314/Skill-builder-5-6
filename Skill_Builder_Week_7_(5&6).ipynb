# %%
#Partial derivative x
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
show(diff(f,x))
# Out:
# (x, y) |--> -2*(x^2 - 3*x)*x*y^2/(x^2*y^2 + 1)^2 + (2*x - 3)/(x^2*y^2 + 1)

# %%
#Partial derivative y
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
show(diff(f,y))
# Out:
# (x, y) |--> -2*(x^2 - 3*x)*x^2*y/(x^2*y^2 + 1)^2

# %%
#Pure x derivative
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_x = diff(f,x)
show(diff(first_x,x))
# Out:
# (x, y) |--> 8*(x^2 - 3*x)*x^2*y^4/(x^2*y^2 + 1)^3 - 4*(2*x - 3)*x*y^2/(x^2*y^2 + 1)^2 - 2*(x^2 - 3*x)*y^2/(x^2*y^2 + 1)^2 + 2/(x^2*y^2 + 1)

# %%
#Pure y derivative
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_y = diff(f,y)
show(diff(first_y,y))
# Out:
# (x, y) |--> 8*(x^2 - 3*x)*x^4*y^2/(x^2*y^2 + 1)^3 - 2*(x^2 - 3*x)*x^2/(x^2*y^2 + 1)^2

# %%
#Pure Mix xy and yx
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_x = diff(f,x)
show(diff(first_x,y))

var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_y = diff(f,y)
show(diff(first_y,x))
# Out:
# (x, y) |--> 8*(x^2 - 3*x)*x^3*y^3/(x^2*y^2 + 1)^3 - 2*(2*x - 3)*x^2*y/(x^2*y^2 + 1)^2 - 4*(x^2 - 3*x)*x*y/(x^2*y^2 + 1)^2
# (x, y) |--> 8*(x^2 - 3*x)*x^3*y^3/(x^2*y^2 + 1)^3 - 2*(2*x - 3)*x^2*y/(x^2*y^2 + 1)^2 - 4*(x^2 - 3*x)*x*y/(x^2*y^2 + 1)^2

# %%
#slope
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_x = diff(f,x)
show(first_x(2,3))
# Out:
# 109/1369

# %%
#slope
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_y = diff(f,y)
show(first_y(2,3))
# Out:
# 48/1369

# %%
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
show(f(2,3))
# Out:
# -2/37

# %%
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
show(f(2.1,2.95))
# Out:
# -0.0479963126642334

# %%
#Pure x   (1/3, 7^0.5)
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_x = diff(f,x)
pure_x = (diff(first_x,x))
pure_x(1/3,(7)^0.5)
# Out:
# 5.06250000000000

# %%
#Pure y  (1/3, 7^0.5)
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_y = diff(f,y)
pure_y = (diff(first_y,y))
pure_y(1/3,(7)^0.5)
# Out:
# -0.0468750000000000

# %%
#Mix  (1/3, 7^0.5)
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_y = diff(f,y)
mix = (diff(first_y,x))
mix(1/3,(7)^0.5)
# Out:
# 0.558088167177687

# %%
#Pure x   (1/3,-(7^0.5)
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_x = diff(f,x)
pure_x = (diff(first_x,x))
pure_x(1/3,-(7^0.5))
# Out:
# 5.06250000000000

# %%
#Pure y  (1/3, 7^0.5)
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_y = diff(f,y)
pure_y = (diff(first_y,y))
pure_y(1/3,-(7^0.5))
# Out:
# -0.0468750000000000

# %%
#Mix  (1/3, 7^0.5)
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
first_y = diff(f,y)
mix = (diff(first_y,x))
mix(1/3,-(7^0.5))
# Out:
# -0.558088167177687

# %%
#1 point boundery c
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(2,0)
# Out:
# -2

# %%
#2 point boundery a
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(-2,0)
# Out:
# 10

# %%
#3 point boundery b
#x1
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(0.2983,3)
# Out:
# -0.447521390238136

# %%
#3 point boundery b
#x2
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(-0.37245,3)
# Out:
# 0.558632506236802

# %%
#4 point boundery d
#x1
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(0.2983,-3)
# Out:
# -0.447521390238136

# %%
#4 point boundery d
#x2
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(-0.37245,-3)
# Out:
# 0.558632506236802

# %%
#1 critical point
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(1/3,(7^0.5))
# Out:
# -0.500000000000000

# %%
#2 critical point
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(1/3,-(7^0.5))
# Out:
# -0.500000000000000

# %%
#End point A
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(-2,3)
# Out:
# 10/37

# %%
#End point B
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(2,3)
# Out:
# -2/37

# %%
#End point C
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(2,-3)
# Out:
# -2/37

# %%
#End point D
var("y")
f(x,y) = ((x^2-3*x)/(1+x^2*y^2))
f(-2,-3)
# Out:
# 10/37

# %%
var("y")
f(x,y) = (x^2-3*x)/(1+x^2*y^2)
plot3d(f,(-2,2),(-3,3))
# Out:
# Graphics3d Object
